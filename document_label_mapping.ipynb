# %% [markdown]
# <a href="https://colab.research.google.com/github/kerryqliu/stats170/blob/irene/document_label_mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:Stats170AB@stats170.c56hn1tg3mkg.us-east-1.rds.amazonaws.com:5432')
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
# mapping document labels to the document # and case id for docs 1-115

# %%
import pandas as pd

# %%
engine.execute("DROP TABLE IF EXISTS documentLabels;")
engine.execute("CREATE TABLE documentLabels ( docID int, caseID int NOT NULL, label float, PRIMARY KEY (docID, caseID));")

# %%
import csv

# %%
with open('/content/drive/Shareddrives/CAPSTONE/Resources/document_labels.csv', 'r') as file:
  read = csv.reader(file, delimiter=',')
  for row in read:
    if row[2] == '5.1':
      # print('inc 5.1', row)
      row[2] = 4
    elif row[2] == '5.2':
      # print('inc 5.2', row)
      row[2] = 3
    elif row[2] == '5.3':
      # print('dec 5.3', row)
      row[2] = 1
    elif row[2] == '5.4':
      # print('norm 5.4', row)
      row[2] = 2
    else:
      # print('n/a')
      row[2] = 0
    print("--", row[0], row[1], row[2])
    engine.execute("INSERT INTO documentLabels VALUES (%s, %s, %s)", row[0], row[1], row[2])
# Out:
# -- 1 -1 1
# -- 2 -1 1
# -- 3 -1 4
# -- 4 11594 1
# -- 5 11594 1
# -- 6 11639 2
# -- 7 11966 1
# -- 8 12464 1
# -- 9 12871 1
# -- 10 14386 0
# -- 11 14414 3
# -- 12 15123 0
# -- 13 17687 2
# -- 14 17817 1
# -- 15 17908 1
# -- 16 20599 0
# -- 17 21813 1
# -- 18 22394 1
# -- 19 24075 0
# -- 20 24476 1
# -- 21 26084 1
# -- 22 26373 0
# -- 23 26506 4
# -- 24 26728 1
# -- 25 26820 1
# -- 26 27405 1
# -- 27 29833 0
# -- 28 31076 1
# -- 29 31356 1
# -- 30 31420 1
# -- 31 31748 4
# -- 32 32002 1
# -- 33 33168 0
# -- 34 33832 0
# -- 35 61505 2
# -- 36 61666 1
# -- 37 61692 1
# -- 38 62201 0
# -- 39 62593 1
# -- 40 64409 1
# -- 41 64979 1
# -- 42 67385 1
# -- 43 67390 1
# -- 44 67892 0
# -- 45 70965 1
# -- 46 72440 3
# -- 47 73523 1
# -- 48 73569 1
# -- 49 73833 0
# -- 50 73871 1
# -- 51 74492 2
# -- 52 74964 1
# -- 53 76758 0
# -- 54 78443 1
# -- 55 79879 2
# -- 56 80477 0
# -- 57 80589 2
# -- 58 81607 1
# -- 59 83536 1
# -- 60 82415 1
# -- 61 82003 2
# -- 62 81845 0
# -- 63 85257 1
# -- 64 86254 4
# -- 65 86522 1
# -- 66 88341 1
# -- 67 89904 0
# -- 68 90631 1
# -- 69 91652 3
# -- 70 95000 2
# -- 71 96704 1
# -- 72 98103 0
# -- 73 98983 1
# -- 74 99585 1
# -- 75 36091 1
# -- 76 36665 1
# -- 77 37815 1
# -- 78 38451 1
# -- 79 39351 1
# -- 80 41068 1
# -- 81 41350 3
# -- 82 41620 1
# -- 83 44456 4
# -- 84 44633 1
# -- 85 45492 0
# -- 86 45504 1
# -- 87 47366 0
# -- 88 50069 1
# -- 89 52492 0
# -- 90 53495 1
# -- 91 53899 1
# -- 92 54202 0
# -- 93 57203 0
# -- 94 57254 1
# -- 95 57804 2
# -- 96 58016 1
# -- 97 58157 1
# -- 98 59093 1
# -- 99 60618 2
# -- 100 61082 1
# -- 101 61207 3
# -- 102 68214 1
# -- 103 75636 1
# -- 104 76603 4
# -- 105 77964 1
# -- 106 82525 1
# -- 107 82691 1
# -- 108 83739 2
# -- 109 83798 3
# -- 110 86049 1
# -- 111 87832 1
# -- 112 88178 1
# -- 113 95139 1
# -- 114 95739 2
# -- 115 97245 1
# -- 116 172631 4
# -- 117 184753 4
# -- 118 273646 4
# -- 119 273841 4
# -- 120 283874 4
# -- 121 364721 4
# -- 122 572763 4
# -- 123 653821 4
# -- 124 734837 4
# -- 125 837462 4
# -- 126 996784 4
# -- 127 206467 3
# -- 128 206504 3
# -- 129 206600 3
# -- 130 206600 3
# -- 131 206852 3
# -- 132 207283 3
# -- 133 207609 3
# -- 134 207877 3
# -- 135 207877 3
# -- 136 207910 3
# -- 137 207910 3
# -- 138 205366 2
# -- 139 205727 2
# -- 140 206597 2
# -- 141 206830 2
# -- 142 206955 2
# -- 143 207261 2
# -- 144 207365 2
# -- 145 207766 2
# -- 146 207813 2
# -- 147 207873 2

# %%
docLabels = "SELECT * FROM documentLabels"
doclabel_df = pd.read_sql_query(docLabels, con=engine)
doclabel_df
# Out:
#      docid  caseid  label
# 0        1      -1    1.0
# 1        2      -1    1.0
# 2        3      -1    4.0
# 3        4   11594    1.0
# 4        5   11594    1.0
# ..     ...     ...    ...
# 142    143  207261    2.0
# 143    144  207365    2.0
# 144    145  207766    2.0
# 145    146  207813    2.0
# 146    147  207873    2.0
#
# [147 rows x 3 columns]

# %%
for index, row in doclabel_df.iterrows():
  print(index, row['docid'], row['caseid'], row['label'])
# Out:
# 0 1.0 -1.0 1.0
# 1 2.0 -1.0 1.0
# 2 3.0 -1.0 4.0
# 3 4.0 11594.0 1.0
# 4 5.0 11594.0 1.0
# 5 6.0 11639.0 2.0
# 6 7.0 11966.0 1.0
# 7 8.0 12464.0 1.0
# 8 9.0 12871.0 1.0
# 9 10.0 14386.0 0.0
# 10 11.0 14414.0 3.0
# 11 12.0 15123.0 0.0
# 12 13.0 17687.0 2.0
# 13 14.0 17817.0 1.0
# 14 15.0 17908.0 1.0
# 15 16.0 20599.0 0.0
# 16 17.0 21813.0 1.0
# 17 18.0 22394.0 1.0
# 18 19.0 24075.0 0.0
# 19 20.0 24476.0 1.0
# 20 21.0 26084.0 1.0
# 21 22.0 26373.0 0.0
# 22 23.0 26506.0 4.0
# 23 24.0 26728.0 1.0
# 24 25.0 26820.0 1.0
# 25 26.0 27405.0 1.0
# 26 27.0 29833.0 0.0
# 27 28.0 31076.0 1.0
# 28 29.0 31356.0 1.0
# 29 30.0 31420.0 1.0
# 30 31.0 31748.0 4.0
# 31 32.0 32002.0 1.0
# 32 33.0 33168.0 0.0
# 33 34.0 33832.0 0.0
# 34 35.0 61505.0 2.0
# 35 36.0 61666.0 1.0
# 36 37.0 61692.0 1.0
# 37 38.0 62201.0 0.0
# 38 39.0 62593.0 1.0
# 39 40.0 64409.0 1.0
# 40 41.0 64979.0 1.0
# 41 42.0 67385.0 1.0
# 42 43.0 67390.0 1.0
# 43 44.0 67892.0 0.0
# 44 45.0 70965.0 1.0
# 45 46.0 72440.0 3.0
# 46 47.0 73523.0 1.0
# 47 48.0 73569.0 1.0
# 48 49.0 73833.0 0.0
# 49 50.0 73871.0 1.0
# 50 51.0 74492.0 2.0
# 51 52.0 74964.0 1.0
# 52 53.0 76758.0 0.0
# 53 54.0 78443.0 1.0
# 54 55.0 79879.0 2.0
# 55 56.0 80477.0 0.0
# 56 57.0 80589.0 2.0
# 57 58.0 81607.0 1.0
# 58 59.0 83536.0 1.0
# 59 60.0 82415.0 1.0
# 60 61.0 82003.0 2.0
# 61 62.0 81845.0 0.0
# 62 63.0 85257.0 1.0
# 63 64.0 86254.0 4.0
# 64 65.0 86522.0 1.0
# 65 66.0 88341.0 1.0
# 66 67.0 89904.0 0.0
# 67 68.0 90631.0 1.0
# 68 69.0 91652.0 3.0
# 69 70.0 95000.0 2.0
# 70 71.0 96704.0 1.0
# 71 72.0 98103.0 0.0
# 72 73.0 98983.0 1.0
# 73 74.0 99585.0 1.0
# 74 75.0 36091.0 1.0
# 75 76.0 36665.0 1.0
# 76 77.0 37815.0 1.0
# 77 78.0 38451.0 1.0
# 78 79.0 39351.0 1.0
# 79 80.0 41068.0 1.0
# 80 81.0 41350.0 3.0
# 81 82.0 41620.0 1.0
# 82 83.0 44456.0 4.0
# 83 84.0 44633.0 1.0
# 84 85.0 45492.0 0.0
# 85 86.0 45504.0 1.0
# 86 87.0 47366.0 0.0
# 87 88.0 50069.0 1.0
# 88 89.0 52492.0 0.0
# 89 90.0 53495.0 1.0
# 90 91.0 53899.0 1.0
# 91 92.0 54202.0 0.0
# 92 93.0 57203.0 0.0
# 93 94.0 57254.0 1.0
# 94 95.0 57804.0 2.0
# 95 96.0 58016.0 1.0
# 96 97.0 58157.0 1.0
# 97 98.0 59093.0 1.0
# 98 99.0 60618.0 2.0
# 99 100.0 61082.0 1.0
# 100 101.0 61207.0 3.0
# 101 102.0 68214.0 1.0
# 102 103.0 75636.0 1.0
# 103 104.0 76603.0 4.0
# 104 105.0 77964.0 1.0
# 105 106.0 82525.0 1.0
# 106 107.0 82691.0 1.0
# 107 108.0 83739.0 2.0
# 108 109.0 83798.0 3.0
# 109 110.0 86049.0 1.0
# 110 111.0 87832.0 1.0
# 111 112.0 88178.0 1.0
# 112 113.0 95139.0 1.0
# 113 114.0 95739.0 2.0
# 114 115.0 97245.0 1.0
# 115 116.0 172631.0 4.0
# 116 117.0 184753.0 4.0
# 117 118.0 273646.0 4.0
# 118 119.0 273841.0 4.0
# 119 120.0 283874.0 4.0
# 120 121.0 364721.0 4.0
# 121 122.0 572763.0 4.0
# 122 123.0 653821.0 4.0
# 123 124.0 734837.0 4.0
# 124 125.0 837462.0 4.0
# 125 126.0 996784.0 4.0
# 126 127.0 206467.0 3.0
# 127 128.0 206504.0 3.0
# 128 129.0 206600.0 3.0
# 129 130.0 206600.0 3.0
# 130 131.0 206852.0 3.0
# 131 132.0 207283.0 3.0
# 132 133.0 207609.0 3.0
# 133 134.0 207877.0 3.0
# 134 135.0 207877.0 3.0
# 135 136.0 207910.0 3.0
# 136 137.0 207910.0 3.0
# 137 138.0 205366.0 2.0
# 138 139.0 205727.0 2.0
# 139 140.0 206597.0 2.0
# 140 141.0 206830.0 2.0
# 141 142.0 206955.0 2.0
# 142 143.0 207261.0 2.0
# 143 144.0 207365.0 2.0
# 144 145.0 207766.0 2.0
# 145 146.0 207813.0 2.0
# 146 147.0 207873.0 2.0
